# %%
# %matplotlib inline  
import pandas as pd
import scipy
import numpy as np
from sklearn import linear_model
import os 
import sys
from datetime import timedelta as td
import dateutil.parser
import matplotlib as plt
import re
import math
import statistics as st
from sklearn import linear_model
from sklearn import preprocessing
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
data_corporate_yeild=pd.read_csv("AAA.csv")
data_corporate_yeild.DATE=pd.to_datetime(data_corporate_yeild.DATE)
data_corporate_yeild.index=data_corporate_yeild.DATE
data_corporate_yeild.drop('DATE',axis=1,inplace=True)
data_corporate_yeild=data_corporate_yeild[data_corporate_yeild.index>='1/1/2001']
data_corporate_yeild=data_corporate_yeild.resample('3M',closed ='left').mean()

# %%
data_corporate_yeild.head(5)
# Out:
#                  AAA
# DATE
# 2001-03-31  7.076667
# 2001-06-30  7.223333
# 2001-09-30  7.106667
# 2001-12-31  6.923333
# 2002-03-31  6.623333

# %%
data_yield=pd.read_excel("yield.xlsx")
data_yield.DATE=pd.to_datetime(data_yield.Date)
data_yield.index=data_yield.Date
data_yield.drop('Date',axis=1,inplace=True)
data_yield=data_yield[data_yield.index>='1/1/2001']
data_yield.dropna(inplace=True)
data_yield['USD_GRM_spread']=data_yield['OTR/USD/10YR (Yield)']-data_yield['Germany Govt 10yr (Yield)']
data_yield.drop(['Germany Govt 10yr (Yield)'],axis=1,inplace=True)
data_yield=data_yield.resample('3M',closed ='left').mean()
data_corporate_yeild['AAA']=data_corporate_yeild['AAA']-data_yield['OTR/USD/10YR (Yield)']

# %%
data_yield.head(5)
# Out:
#             OTR/USD/10YR (Yield)  USD_GRM_spread
# Date
# 2001-03-31              5.631395        0.869411
# 2001-06-30              5.850798        0.865767
# 2001-09-30              5.566358        0.668132
# 2001-12-31              5.318723        0.695084
# 2002-03-31              5.650477        0.655690

# %%
data_yield.plot()

# %% [markdown]
# ### Use PPU data as y

# %%
metro_level_rent_price=pd.read_csv('metro_other_index.csv')

# %%
rent_index=metro_level_rent_price[metro_level_rent_price['DATA_TYPE']=='PPU']
err_index=metro_level_rent_price[metro_level_rent_price['DATA_TYPE']=='ERR']

# %%
rent_index_ret=rent_index[rent_index['SECTOR'].str.contains('RET')]
rent_index_ret_t=rent_index_ret[pd.isnull(rent_index_ret['QUALIFIERS'])]
rent_index_apt=rent_index[rent_index['SECTOR'].str.contains('APT')]
rent_index_apt_t=rent_index_apt[pd.isnull(rent_index_apt['QUALIFIERS'])]
rent_index_off=rent_index[rent_index['SECTOR'].str.contains('OFF')]
rent_index_off_t=rent_index_off[pd.isnull(rent_index_off['QUALIFIERS'])]
rent_index_ind=rent_index[rent_index['SECTOR'].str.contains('IND')]
rent_index_ind_t=rent_index_ind[pd.isnull(rent_index_ind['QUALIFIERS'])]
rent_index=rent_index_ret_t
rent_index=rent_index.append(rent_index_apt_t)
rent_index=rent_index.append(rent_index_off_t)
rent_index=rent_index.append(rent_index_ind_t)
rent_index=rent_index[~rent_index.MetroArea.str.contains('Market')]
rent_index.drop(['DATA_TYPE','Name','QUALIFIERS','SubMarket'],axis=1,inplace=True)
rent_index.reset_index(inplace=True,drop=True)

# %%
err_index_ret=err_index[err_index['SECTOR'].str.contains('RET')]
err_index_ret_t=err_index_ret[pd.isnull(err_index_ret['QUALIFIERS'])]
err_index_apt=err_index[err_index['SECTOR'].str.contains('APT')]
err_index_apt_t=err_index_apt[pd.isnull(err_index_apt['QUALIFIERS'])]
err_index_off=err_index[err_index['SECTOR'].str.contains('OFF')]
err_index_off_t=err_index_off[pd.isnull(err_index_off['QUALIFIERS'])]
err_index_ind=err_index[err_index['SECTOR'].str.contains('IND')]
err_index_ind_t=err_index_ind[pd.isnull(err_index_ind['QUALIFIERS'])]
err_index=err_index_ret_t
err_index=err_index.append(err_index_apt_t)
err_index=err_index.append(err_index_off_t)
err_index=err_index.append(err_index_ind_t)
err_index=err_index[~err_index.MetroArea.str.contains('Market')]
err_index.drop(['DATA_TYPE','Name','QUALIFIERS','SubMarket'],axis=1,inplace=True)
err_index.reset_index(inplace=True,drop=True)

# %%
err_index.head(5)
# Out:
#         Date MetroArea SECTOR  value
# 0   1/1/2001     Tampa    RET    NaN
# 1   4/1/2001     Tampa    RET    NaN
# 2   7/1/2001     Tampa    RET    NaN
# 3  10/1/2001     Tampa    RET    NaN
# 4   1/1/2002     Tampa    RET    NaN

# %%
region_data=pd.read_csv('region.csv')
region_data_rent_index=region_data[region_data['DATA_TYPE']=='PP1']
state_data=pd.read_csv('states.csv')
state_data_rent_index=state_data[state_data['DATA_TYPE']=='PP1']
state_data_rent_index.reset_index(inplace=True,drop=True)

# %%
metro_areas=list(set(rent_index.MetroArea))

# %%
states=list(set(state_data_rent_index.GEOGRAPHY))
cities_table=pd.read_excel('city map.xlsx',sheetname='city')
cities_table.dropna(inplace=True)
state_table=pd.read_excel('city map.xlsx',sheetname='state')
region_table=pd.read_excel('city map.xlsx',sheetname='region')
region_table.dropna(inplace=True)
state_table=state_table.iloc[:,0:2]

# %%
regions=list(set(region_data_rent_index.GEOGRAPHY))

cities_table=pd.read_excel('city map.xlsx',sheetname='city')
cities_table.dropna(inplace=True)
state_table=pd.read_excel('city map.xlsx',sheetname='state')
region_table=pd.read_excel('city map.xlsx',sheetname='region')
region_table.dropna(inplace=True)

state_region_dict={}
for i in range(region_table.shape[0]):
    temp=region_table.iloc[i]
    states=[string.replace(' ','') for string in temp.state.split(',')]
    for state in states:
        state_region_dict[state]=temp['RCA region']

state_table=state_table.iloc[:,0:2]

state_breif_dict={}
state_table.state=state_table.state.str.strip()
state_table.breif=state_table.breif.str.strip()
for i in range(state_table.shape[0]):
    state_breif_dict[state_table.iloc[i,0]]=state_table.iloc[i,1]

city_region_dict={}
for i in range(cities_table.shape[0]):
    city_region_dict[cities_table.iloc[i,0]]=state_region_dict[state_breif_dict[cities_table.iloc[i,1]]]

dict1={}
for metro in metro_areas:
    if metro=='St Louis':
        dict1[metro]='RCA - US Midwest'
    elif metro=='Raleigh/Durham':
        dict1[metro]='RCA - US Southeast'
    elif metro=='Phila Metro':
        dict1[metro]='RCA - Mid-Atlantic'
    elif metro=='LA Metro':
        dict1[metro]='RCA - West'
    elif metro=='DC Metro':
        dict1[metro]='RCA - Mid-Atlantic'
    elif metro=='NYC Metro':
        dict1[metro]='RCA - Mid-Atlantic'
    elif metro=='SW Florida':
        dict1[metro]='RCA - US Southeast'
    elif metro=='So Fla':
        dict1[metro]='RCA - US Southeast'
    elif metro=='Birmingham(AL)':
        dict1[metro]='RCA - US Southeast'
    elif metro=='SF Metro':
        dict1[metro]='RCA - West'
    else:
        dict1[metro]=city_region_dict[metro]

# %%
city_state_dict={}
for i in range(cities_table.shape[0]):
    city_state_dict[cities_table.iloc[i,0]]=cities_table.iloc[i,1]
dict2={}
for metro in metro_areas:
    if metro=='St Louis':
        dict2[metro]='Missouri'
    elif metro=='Raleigh/Durham':
        dict2[metro]='North Carolina'
    elif metro=='Phila Metro':
        dict2[metro]='Pennsylvania'
    elif metro=='LA Metro':
        dict2[metro]='California'
    elif metro=='DC Metro':
        dict2[metro]='Maryland'
    elif metro=='NYC Metro':
        dict2[metro]='New York'
    elif metro=='SW Florida':
        dict2[metro]='Florida'
    elif metro=='So Fla':
        dict2[metro]='Florida'
    elif metro=='Birmingham(AL)':
        dict2[metro]='Alabama'
    elif metro=='SF Metro':
        dict2[metro]='California'
    else:
        dict2[metro]=city_state_dict[metro]

# %%
def fillhole(X,Y):
    Y=Y.interpolate()
    
    X.reset_index(inplace=True)
    Y.reset_index(inplace=True)
    Y_return=Y.value
    X_return=X.value
    x_column=list(X.columns).index('value')
    y_column=list(Y.columns).index('value')
    ret=pd.concat([X_return,Y_return],axis=1)
    ret.columns=['X_ret','Y_ret']
    ret_na=ret.dropna()
    Y_ret=ret_na.Y_ret
    X_ret=ret_na.X_ret
    Y_ret = sm.add_constant(Y_ret, prepend=False)
    model = sm.OLS(X_ret,Y_ret)
    res=model.fit()
    Y_return=sm.add_constant(Y_return, prepend=False)
    for i in range(X.shape[0]):
        if pd.isnull(X.iloc[i,x_column]):
            X.iloc[i,x_column]=Y_return.iloc[i,:].dot(np.array(res.params))
    X.set_index('index',inplace=True)
    return [X,res]

# %%
for metro_1 in metro_areas:
    for sector_1 in ['APT','OFF','IND','RET']:
        state_1=dict2[metro_1]
        Y=state_data_rent_index[state_data_rent_index['GEOGRAPHY']==state_1]
        Y=Y[Y['SECTOR']==sector_1]
        X=rent_index[rent_index['MetroArea']==metro_1]
        X=X[X['SECTOR']==sector_1]
        if X.shape[0]!=0: 
            X=fillhole(X,Y)[0]
            for i in range(X.shape[0]):
                rent_index.iloc[X.index[i],3]=X.iloc[i,3]
        else:
            pass
rent_index.dropna(inplace=True)

# %%
region_data=pd.read_csv('region.csv')
region_data_err_index=region_data[region_data['DATA_TYPE']=='REX']
state_data=pd.read_csv('states.csv')
state_data_err_index=state_data[state_data['DATA_TYPE']=='REX']
state_data_err_index.reset_index(inplace=True,drop=True)

# %%
for metro_1 in metro_areas:
    for sector_1 in ['APT','OFF','IND','RET']:
        region_1=dict1[metro_1]
        Y=region_data_err_index[region_data_err_index['GEOGRAPHY']==region_1]
        Y=Y[Y['SECTOR']==sector_1]
        X=err_index[err_index['MetroArea']==metro_1]
        X=X[X['SECTOR']==sector_1]
        if X.shape[0]!=0:
            [X,res]=fillhole(X,Y)
            print(res.summary())
            for i in range(X.shape[0]):
                err_index.iloc[X.index[i],3]=X.iloc[i,3]
        else:
            pass
err_index.dropna(inplace=True)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.888
# Model:                            OLS   Adj. R-squared:                  0.886
# Method:                 Least Squares   F-statistic:                     411.4
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           2.34e-26
# Time:                        17:00:14   Log-Likelihood:                -53.975
# No. Observations:                  54   AIC:                             111.9
# Df Residuals:                      52   BIC:                             115.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          0.6765      0.033     20.282      0.000         0.610     0.743
# const          4.6061      0.602      7.646      0.000         3.397     5.815
# ==============================================================================
# Omnibus:                       70.189   Durbin-Watson:                   0.052
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                5.696
# Skew:                           0.148   Prob(JB):                       0.0580
# Kurtosis:                       1.437   Cond. No.                         120.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.357
# Model:                            OLS   Adj. R-squared:                  0.345
# Method:                 Least Squares   F-statistic:                     28.90
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           1.82e-06
# Time:                        17:00:15   Log-Likelihood:                -58.362
# No. Observations:                  54   AIC:                             120.7
# Df Residuals:                      52   BIC:                             124.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          0.1586      0.029      5.376      0.000         0.099     0.218
# const         16.6048      0.948     17.509      0.000        14.702    18.508
# ==============================================================================
# Omnibus:                        2.306   Durbin-Watson:                   0.097
# Prob(Omnibus):                  0.316   Jarque-Bera (JB):                1.457
# Skew:                           0.347   Prob(JB):                        0.483
# Kurtosis:                       3.407   Cond. No.                         309.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.526
# Model:                            OLS   Adj. R-squared:                  0.517
# Method:                 Least Squares   F-statistic:                     57.80
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           5.43e-10
# Time:                        17:00:15   Log-Likelihood:                 10.314
# No. Observations:                  54   AIC:                            -16.63
# Df Residuals:                      52   BIC:                            -12.65
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          0.6309      0.083      7.602      0.000         0.464     0.797
# const          1.6607      0.546      3.040      0.004         0.565     2.757
# ==============================================================================
# Omnibus:                        5.563   Durbin-Watson:                   0.097
# Prob(Omnibus):                  0.062   Jarque-Bera (JB):                2.455
# Skew:                          -0.200   Prob(JB):                        0.293
# Kurtosis:                       2.035   Cond. No.                         133.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.677
# Model:                            OLS   Adj. R-squared:                  0.671
# Method:                 Least Squares   F-statistic:                     109.1
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           2.28e-14
# Time:                        17:00:15   Log-Likelihood:                -82.826
# No. Observations:                  54   AIC:                             169.7
# Df Residuals:                      52   BIC:                             173.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          0.8400      0.080     10.443      0.000         0.679     1.001
# const          2.4385      1.701      1.434      0.158        -0.975     5.852
# ==============================================================================
# Omnibus:                        2.637   Durbin-Watson:                   0.076
# Prob(Omnibus):                  0.268   Jarque-Bera (JB):                2.324
# Skew:                          -0.405   Prob(JB):                        0.313
# Kurtosis:                       2.387   Cond. No.                         232.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.977
# Model:                            OLS   Adj. R-squared:                  0.976
# Method:                 Least Squares   F-statistic:                     2203.
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           3.03e-44
# Time:                        17:00:15   Log-Likelihood:                -23.735
# No. Observations:                  54   AIC:                             51.47
# Df Residuals:                      52   BIC:                             55.45
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          1.1541      0.025     46.935      0.000         1.105     1.203
# const         -1.1116      0.311     -3.573      0.001        -1.736    -0.487
# ==============================================================================
# Omnibus:                        6.325   Durbin-Watson:                   0.215
# Prob(Omnibus):                  0.042   Jarque-Bera (JB):                4.407
# Skew:                           0.552   Prob(JB):                        0.110
# Kurtosis:                       2.141   Cond. No.                         76.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.962
# Model:                            OLS   Adj. R-squared:                  0.961
# Method:                 Least Squares   F-statistic:                     1302.
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           1.76e-38
# Time:                        17:00:15   Log-Likelihood:                -56.534
# No. Observations:                  54   AIC:                             117.1
# Df Residuals:                      52   BIC:                             121.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          1.8769      0.052     36.081      0.000         1.773     1.981
# const        -14.1383      1.072    -13.193      0.000       -16.289   -11.988
# ==============================================================================
# Omnibus:                        7.174   Durbin-Watson:                   0.157
# Prob(Omnibus):                  0.028   Jarque-Bera (JB):                3.145
# Skew:                           0.308   Prob(JB):                        0.208
# Kurtosis:                       1.991   Cond. No.                         231.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.559
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     65.90
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           8.29e-11
# Time:                        17:00:15   Log-Likelihood:                -4.3405
# No. Observations:                  54   AIC:                             12.68
# Df Residuals:                      52   BIC:                             16.66
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          0.9558      0.118      8.118      0.000         0.720     1.192
# const          0.4334      0.690      0.628      0.533        -0.951     1.818
# ==============================================================================
# Omnibus:                       14.309   Durbin-Watson:                   0.056
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                3.428
# Skew:                           0.102   Prob(JB):                        0.180
# Kurtosis:                       1.783   Cond. No.                         114.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.780
# Model:                            OLS   Adj. R-squared:                  0.776
# Method:                 Least Squares   F-statistic:                     184.6
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           9.68e-19
# Time:                        17:00:15   Log-Likelihood:                -74.226
# No. Observations:                  54   AIC:                             152.5
# Df Residuals:                      52   BIC:                             156.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          1.0625      0.078     13.586      0.000         0.906     1.219
# const         -1.8780      1.532     -1.226      0.226        -4.953     1.197
# ==============================================================================
# Omnibus:                        2.686   Durbin-Watson:                   0.133
# Prob(Omnibus):                  0.261   Jarque-Bera (JB):                2.368
# Skew:                          -0.411   Prob(JB):                        0.306
# Kurtosis:                       2.387   Cond. No.                         227.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.986
# Model:                            OLS   Adj. R-squared:                  0.986
# Method:                 Least Squares   F-statistic:                     3648.
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           7.70e-50
# Time:                        17:00:15   Log-Likelihood:                 3.5830
# No. Observations:                  54   AIC:                            -3.166
# Df Residuals:                      52   BIC:                            0.8119
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          0.7682      0.013     60.402      0.000         0.743     0.794
# const          2.4329      0.180     13.481      0.000         2.071     2.795
# ==============================================================================
# Omnibus:                        3.790   Durbin-Watson:                   0.219
# Prob(Omnibus):                  0.150   Jarque-Bera (JB):                3.023
# Skew:                           0.570   Prob(JB):                        0.221
# Kurtosis:                       3.205   Cond. No.                         81.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.875
# Method:                 Least Squares   F-statistic:                     371.2
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           2.48e-25
# Time:                        17:00:15   Log-Likelihood:                -29.113
# No. Observations:                  54   AIC:                             62.23
# Df Residuals:                      52   BIC:                             66.20
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          0.8445      0.044     19.267      0.000         0.757     0.932
# const          3.2051      0.909      3.525      0.001         1.381     5.030
# ==============================================================================
# Omnibus:                        1.040   Durbin-Watson:                   0.165
# Prob(Omnibus):                  0.595   Jarque-Bera (JB):                0.930
# Skew:                          -0.083   Prob(JB):                        0.628
# Kurtosis:                       2.379   Cond. No.                         329.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.065
# Model:                            OLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     3.644
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):             0.0618
# Time:                        17:00:16   Log-Likelihood:                -17.623
# No. Observations:                  54   AIC:                             39.25
# Df Residuals:                      52   BIC:                             43.22
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          0.3596      0.188      1.909      0.062        -0.018     0.738
# const          5.9534      1.119      5.319      0.000         3.708     8.199
# ==============================================================================
# Omnibus:                        5.760   Durbin-Watson:                   0.058
# Prob(Omnibus):                  0.056   Jarque-Bera (JB):                5.162
# Skew:                           0.677   Prob(JB):                       0.0757
# Kurtosis:                       2.322   Cond. No.                         147.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.690
# Model:                            OLS   Adj. R-squared:                  0.684
# Method:                 Least Squares   F-statistic:                     115.9
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           7.71e-15
# Time:                        17:00:16   Log-Likelihood:                -70.534
# No. Observations:                  54   AIC:                             145.1
# Df Residuals:                      52   BIC:                             149.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          0.9097      0.085     10.763      0.000         0.740     1.079
# const          3.5993      1.570      2.292      0.026         0.448     6.750
# ==============================================================================
# Omnibus:                        4.124   Durbin-Watson:                   0.070
# Prob(Omnibus):                  0.127   Jarque-Bera (JB):                2.426
# Skew:                           0.295   Prob(JB):                        0.297
# Kurtosis:                       2.146   Cond. No.                         236.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.974
# Model:                            OLS   Adj. R-squared:                  0.974
# Method:                 Least Squares   F-statistic:                     1984.
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           4.32e-43
# Time:                        17:00:16   Log-Likelihood:                -5.7826
# No. Observations:                  54   AIC:                             15.57
# Df Residuals:                      52   BIC:                             19.54
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          1.1190      0.025     44.542      0.000         1.069     1.169
# const          1.3652      0.286      4.773      0.000         0.791     1.939
# ==============================================================================
# Omnibus:                        7.880   Durbin-Watson:                   0.060
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):                2.632
# Skew:                           0.086   Prob(JB):                        0.268
# Kurtosis:                       1.932   Cond. No.                         87.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.861
# Model:                            OLS   Adj. R-squared:                  0.858
# Method:                 Least Squares   F-statistic:                     321.0
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           6.68e-24
# Time:                        17:00:16   Log-Likelihood:                -45.497
# No. Observations:                  54   AIC:                             94.99
# Df Residuals:                      52   BIC:                             98.97
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          0.9665      0.054     17.916      0.000         0.858     1.075
# const          6.3899      1.131      5.651      0.000         4.121     8.659
# ==============================================================================
# Omnibus:                        3.551   Durbin-Watson:                   0.087
# Prob(Omnibus):                  0.169   Jarque-Bera (JB):                1.820
# Skew:                          -0.116   Prob(JB):                        0.402
# Kurtosis:                       2.131   Cond. No.                         305.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.578
# Model:                            OLS   Adj. R-squared:                  0.570
# Method:                 Least Squares   F-statistic:                     71.35
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           2.52e-11
# Time:                        17:00:16   Log-Likelihood:                 5.9834
# No. Observations:                  54   AIC:                            -7.967
# Df Residuals:                      52   BIC:                            -3.989
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          0.8238      0.098      8.447      0.000         0.628     1.020
# const          3.7727      0.521      7.245      0.000         2.728     4.818
# ==============================================================================
# Omnibus:                        2.782   Durbin-Watson:                   0.098
# Prob(Omnibus):                  0.249   Jarque-Bera (JB):                2.657
# Skew:                           0.519   Prob(JB):                        0.265
# Kurtosis:                       2.681   Cond. No.                         95.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.700
# Model:                            OLS   Adj. R-squared:                  0.695
# Method:                 Least Squares   F-statistic:                     121.6
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           3.21e-15
# Time:                        17:00:16   Log-Likelihood:                -83.838
# No. Observations:                  54   AIC:                             171.7
# Df Residuals:                      52   BIC:                             175.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          1.3132      0.119     11.025      0.000         1.074     1.552
# const         -0.1700      2.008     -0.085      0.933        -4.200     3.860
# ==============================================================================
# Omnibus:                       11.844   Durbin-Watson:                   0.038
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):                3.110
# Skew:                           0.048   Prob(JB):                        0.211
# Kurtosis:                       1.828   Cond. No.                         214.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.984
# Model:                            OLS   Adj. R-squared:                  0.984
# Method:                 Least Squares   F-statistic:                     3215.
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           1.97e-48
# Time:                        17:00:16   Log-Likelihood:                -32.570
# No. Observations:                  54   AIC:                             69.14
# Df Residuals:                      52   BIC:                             73.12
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          1.2722      0.022     56.697      0.000         1.227     1.317
# const         -2.5236      0.405     -6.227      0.000        -3.337    -1.710
# ==============================================================================
# Omnibus:                       14.631   Durbin-Watson:                   0.057
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                4.203
# Skew:                          -0.322   Prob(JB):                        0.122
# Kurtosis:                       1.795   Cond. No.                         120.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.967
# Model:                            OLS   Adj. R-squared:                  0.966
# Method:                 Least Squares   F-statistic:                     1525.
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           3.31e-40
# Time:                        17:00:16   Log-Likelihood:                -45.360
# No. Observations:                  54   AIC:                             94.72
# Df Residuals:                      52   BIC:                             98.70
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          0.9055      0.023     39.055      0.000         0.859     0.952
# const          6.1152      0.745      8.204      0.000         4.619     7.611
# ==============================================================================
# Omnibus:                        2.853   Durbin-Watson:                   0.172
# Prob(Omnibus):                  0.240   Jarque-Bera (JB):                2.713
# Skew:                          -0.528   Prob(JB):                        0.258
# Kurtosis:                       2.700   Cond. No.                         309.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.636
# Model:                            OLS   Adj. R-squared:                  0.629
# Method:                 Least Squares   F-statistic:                     90.72
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           5.44e-13
# Time:                        17:00:16   Log-Likelihood:                -45.122
# No. Observations:                  54   AIC:                             94.24
# Df Residuals:                      52   BIC:                             98.22
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          2.2065      0.232      9.525      0.000         1.742     2.671
# const         -4.2199      1.525     -2.767      0.008        -7.280    -1.160
# ==============================================================================
# Omnibus:                        3.422   Durbin-Watson:                   0.089
# Prob(Omnibus):                  0.181   Jarque-Bera (JB):                2.551
# Skew:                           0.381   Prob(JB):                        0.279
# Kurtosis:                       2.256   Cond. No.                         133.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.909
# Model:                            OLS   Adj. R-squared:                  0.907
# Method:                 Least Squares   F-statistic:                     518.5
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           1.04e-28
# Time:                        17:00:16   Log-Likelihood:                -51.602
# No. Observations:                  54   AIC:                             107.2
# Df Residuals:                      52   BIC:                             111.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          1.0273      0.045     22.770      0.000         0.937     1.118
# const          3.3314      0.954      3.492      0.001         1.417     5.246
# ==============================================================================
# Omnibus:                        6.557   Durbin-Watson:                   0.088
# Prob(Omnibus):                  0.038   Jarque-Bera (JB):                3.767
# Skew:                           0.449   Prob(JB):                        0.152
# Kurtosis:                       2.068   Cond. No.                         232.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.895
# Model:                            OLS   Adj. R-squared:                  0.893
# Method:                 Least Squares   F-statistic:                     444.4
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           3.89e-27
# Time:                        17:00:17   Log-Likelihood:                -12.685
# No. Observations:                  54   AIC:                             29.37
# Df Residuals:                      52   BIC:                             33.35
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          0.6018      0.029     21.080      0.000         0.544     0.659
# const          3.7566      0.325     11.558      0.000         3.104     4.409
# ==============================================================================
# Omnibus:                        5.250   Durbin-Watson:                   0.071
# Prob(Omnibus):                  0.072   Jarque-Bera (JB):                5.195
# Skew:                           0.745   Prob(JB):                       0.0745
# Kurtosis:                       2.701   Cond. No.                         87.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.300
# Model:                            OLS   Adj. R-squared:                  0.286
# Method:                 Least Squares   F-statistic:                     22.25
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           1.84e-05
# Time:                        17:00:17   Log-Likelihood:                -101.93
# No. Observations:                  54   AIC:                             207.9
# Df Residuals:                      52   BIC:                             211.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          0.7235      0.153      4.716      0.000         0.416     1.031
# const          2.8998      3.215      0.902      0.371        -3.552     9.351
# ==============================================================================
# Omnibus:                       16.643   Durbin-Watson:                   0.037
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                3.805
# Skew:                          -0.176   Prob(JB):                        0.149
# Kurtosis:                       1.748   Cond. No.                         305.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.504
# Model:                            OLS   Adj. R-squared:                  0.495
# Method:                 Least Squares   F-statistic:                     52.87
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           1.83e-09
# Time:                        17:00:17   Log-Likelihood:                -23.789
# No. Observations:                  54   AIC:                             51.58
# Df Residuals:                      52   BIC:                             55.56
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          1.2307      0.169      7.271      0.000         0.891     1.570
# const         -0.3078      0.904     -0.341      0.735        -2.121     1.506
# ==============================================================================
# Omnibus:                        0.082   Durbin-Watson:                   0.096
# Prob(Omnibus):                  0.960   Jarque-Bera (JB):                0.258
# Skew:                          -0.061   Prob(JB):                        0.879
# Kurtosis:                       2.684   Cond. No.                         95.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.746
# Model:                            OLS   Adj. R-squared:                  0.741
# Method:                 Least Squares   F-statistic:                     153.0
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           4.12e-17
# Time:                        17:00:17   Log-Likelihood:                -67.331
# No. Observations:                  54   AIC:                             138.7
# Df Residuals:                      52   BIC:                             142.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          1.0852      0.088     12.368      0.000         0.909     1.261
# const          0.0446      1.479      0.030      0.976        -2.924     3.013
# ==============================================================================
# Omnibus:                        5.530   Durbin-Watson:                   0.087
# Prob(Omnibus):                  0.063   Jarque-Bera (JB):                5.062
# Skew:                          -0.749   Prob(JB):                       0.0796
# Kurtosis:                       3.056   Cond. No.                         214.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                     8916.
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           7.76e-60
# Time:                        17:00:17   Log-Likelihood:                 14.234
# No. Observations:                  54   AIC:                            -24.47
# Df Residuals:                      52   BIC:                            -20.49
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          1.1494      0.012     94.422      0.000         1.125     1.174
# const         -1.1677      0.154     -7.581      0.000        -1.477    -0.859
# ==============================================================================
# Omnibus:                        7.114   Durbin-Watson:                   0.757
# Prob(Omnibus):                  0.029   Jarque-Bera (JB):                9.043
# Skew:                          -0.399   Prob(JB):                       0.0109
# Kurtosis:                       4.839   Cond. No.                         76.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.818
# Model:                            OLS   Adj. R-squared:                  0.815
# Method:                 Least Squares   F-statistic:                     234.4
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           6.58e-21
# Time:                        17:00:17   Log-Likelihood:                -92.978
# No. Observations:                  54   AIC:                             190.0
# Df Residuals:                      52   BIC:                             193.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          1.5640      0.102     15.310      0.000         1.359     1.769
# const         -8.5704      2.104     -4.073      0.000       -12.793    -4.348
# ==============================================================================
# Omnibus:                       10.939   Durbin-Watson:                   0.047
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):                3.060
# Skew:                           0.097   Prob(JB):                        0.217
# Kurtosis:                       1.850   Cond. No.                         231.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ...
# Df Residuals:                      52   BIC:                             145.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          0.8899      0.071     12.546      0.000         0.748     1.032
# const          2.8558      1.390      2.055      0.045         0.067     5.645
# ==============================================================================
# Omnibus:                        7.984   Durbin-Watson:                   0.146
# Prob(Omnibus):                  0.018   Jarque-Bera (JB):                7.167
# Skew:                          -0.838   Prob(JB):                       0.0278
# Kurtosis:                       3.613   Cond. No.                         227.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.951
# Method:                 Least Squares   F-statistic:                     1019.
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           7.77e-36
# Time:                        17:00:23   Log-Likelihood:                -59.499
# No. Observations:                  54   AIC:                             123.0
# Df Residuals:                      52   BIC:                             127.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          1.5583      0.049     31.927      0.000         1.460     1.656
# const         -6.2383      0.901     -6.926      0.000        -8.046    -4.431
# ==============================================================================
# Omnibus:                        3.160   Durbin-Watson:                   0.132
# Prob(Omnibus):                  0.206   Jarque-Bera (JB):                1.970
# Skew:                           0.238   Prob(JB):                        0.373
# Kurtosis:                       2.195   Cond. No.                         165.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.928
# Method:                 Least Squares   F-statistic:                     679.8
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           1.58e-31
# Time:                        17:00:23   Log-Likelihood:                -62.194
# No. Observations:                  54   AIC:                             128.4
# Df Residuals:                      52   BIC:                             132.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          1.8431      0.071     26.073      0.000         1.701     1.985
# const        -18.9864      1.890    -10.048      0.000       -22.778   -15.195
# ==============================================================================
# Omnibus:                        3.901   Durbin-Watson:                   0.066
# Prob(Omnibus):                  0.142   Jarque-Bera (JB):                3.766
# Skew:                           0.606   Prob(JB):                        0.152
# Kurtosis:                       2.545   Cond. No.                         476.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.505
# Model:                            OLS   Adj. R-squared:                  0.496
# Method:                 Least Squares   F-statistic:                     53.13
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           1.71e-09
# Time:                        17:00:23   Log-Likelihood:                -77.775
# No. Observations:                  54   AIC:                             159.6
# Df Residuals:                      52   BIC:                             163.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          2.5127      0.345      7.289      0.000         1.821     3.204
# const         -9.7914      2.699     -3.627      0.001       -15.208    -4.375
# ==============================================================================
# Omnibus:                        1.774   Durbin-Watson:                   0.033
# Prob(Omnibus):                  0.412   Jarque-Bera (JB):                1.660
# Skew:                           0.327   Prob(JB):                        0.436
# Kurtosis:                       2.443   Cond. No.                         152.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.908
# Model:                            OLS   Adj. R-squared:                  0.906
# Method:                 Least Squares   F-statistic:                     514.4
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           1.25e-28
# Time:                        17:00:23   Log-Likelihood:                -93.252
# No. Observations:                  54   AIC:                             190.5
# Df Residuals:                      52   BIC:                             194.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          1.3867      0.061     22.680      0.000         1.264     1.509
# const         -2.3547      1.498     -1.572      0.122        -5.360     0.651
# ==============================================================================
# Omnibus:                        5.698   Durbin-Watson:                   0.094
# Prob(Omnibus):                  0.058   Jarque-Bera (JB):                2.475
# Skew:                          -0.198   Prob(JB):                        0.290
# Kurtosis:                       2.029   Cond. No.                         195.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.884
# Model:                            OLS   Adj. R-squared:                  0.882
# Method:                 Least Squares   F-statistic:                     397.7
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           5.10e-26
# Time:                        17:00:23   Log-Likelihood:                -68.316
# No. Observations:                  54   AIC:                             140.6
# Df Residuals:                      52   BIC:                             144.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          1.1460      0.057     19.943      0.000         1.031     1.261
# const          0.1460      1.060      0.138      0.891        -1.982     2.274
# ==============================================================================
# Omnibus:                       43.925   Durbin-Watson:                   0.048
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                5.574
# Skew:                           0.277   Prob(JB):                       0.0616
# Kurtosis:                       1.527   Cond. No.                         165.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.501
# Model:                            OLS   Adj. R-squared:                  0.491
# Method:                 Least Squares   F-statistic:                     52.12
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           2.21e-09
# Time:                        17:00:24   Log-Likelihood:                -60.446
# No. Observations:                  54   AIC:                             124.9
# Df Residuals:                      52   BIC:                             128.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          0.4941      0.068      7.219      0.000         0.357     0.631
# const         13.9090      1.829      7.603      0.000        10.238    17.580
# ==============================================================================
# Omnibus:                        8.055   Durbin-Watson:                   0.055
# Prob(Omnibus):                  0.018   Jarque-Bera (JB):                3.456
# Skew:                           0.342   Prob(JB):                        0.178
# Kurtosis:                       1.966   Cond. No.                         476.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.625
# Model:                            OLS   Adj. R-squared:                  0.618
# Method:                 Least Squares   F-statistic:                     86.64
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           1.16e-12
# Time:                        17:00:24   Log-Likelihood:                 14.532
# No. Observations:                  54   AIC:                            -25.06
# Df Residuals:                      52   BIC:                            -21.09
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          0.5807      0.062      9.308      0.000         0.456     0.706
# const          2.7013      0.489      5.530      0.000         1.721     3.682
# ==============================================================================
# Omnibus:                       12.931   Durbin-Watson:                   0.037
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                4.389
# Skew:                           0.388   Prob(JB):                        0.111
# Kurtosis:                       1.838   Cond. No.                         152.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  X_ret   R-squared:                       0.886
# Model:                            OLS   Adj. R-squared:                  0.884
# Method:                 Least Squares   F-statistic:                     405.6
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           3.24e-26
# Time:                        17:00:24   Log-Likelihood:                -63.297
# No. Observations:                  54   AIC:                             130.6
# Df Residuals:                      52   BIC:                             134.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Y_ret          0.7071      0.035     20.140      0.000         0.637     0.778
# const          9.2005      0.860     10.697      0.000         7.475    10.926
# ==============================================================================
# Omnibus:                        1.248   Durbin-Watson:                   0.097
# Prob(Omnibus):                  0.536   Jarque-Bera (JB):                1.277
# Skew:                          -0.296   Prob(JB):                        0.528
# Kurtosis:                       2.535   Cond. No.                         195.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#len(set(rent_index.MetroArea))
#len(set(err_index.MetroArea))

# %%
#len(err_index[pd.isnull(err_index.value)])

# %% [markdown]
#  function Y = holefillTS(iX,iY)
#
# % hole fill beginning open hole
# iVldIdx = find(~isnan(iY),1,'first');
# iYsub = iY(iVldIdx) * iX(1:(iVldIdx-1)) / iX(iVldIdx);
# iY(1:(iVldIdx-1)) = iYsub;
#
# % hole fill ending open hole
# iVldIdx = find(~isnan(iY),1,'last');
# iYsub = iY(iVldIdx) * iX((iVldIdx+1):end) / iX(iVldIdx);
# iY(iVldIdx+1:end) = iYsub;
#
# % hole fill any closed hole
# iBeginIdx = find(isnan(iY),1,'first');
# while (~isempty(iBeginIdx))
#   iEndIdx = find(~isnan(iY(iBeginIdx:end)),1,'first');
# iEndIdx = iBeginIdx + iEndIdx - 2;
# nHoles = iEndIdx - iBeginIdx + 1;
#
# iXtotal = log(iX(iEndIdx+1)/iX(iBeginIdx-1));
# iYtotal = log(iY(iEndIdx+1)/iY(iBeginIdx-1));
#    %iYsub = iY(iBeginIdx-1) * exp(1/iXtotal*log(iX(iBeginIdx:iEndIdx)/iX(iBeginIdx-1))+iYtotal/(iEndIdx-iBeginIdx+2)*(1:(iEndIdx-iBeginIdx+1))');
#    %iYsub = iY(iBeginIdx-1) * exp(iYtotal/(nHoles+1)*(1:nHoles)' + iXtotal/(nHoles+1)*(1:nHoles)' - iXtotal);
# iYsub = iY(iBeginIdx-1) * exp(iYtotal/(nHoles+1)*(1:nHoles)' + log(iX(iBeginIdx:iEndIdx)/iX(iBeginIdx-1)) - iXtotal);
# iY(iBeginIdx:iEndIdx) = iYsub;
#
#   iBeginIdx = find(isnan(iY),1,'first');
# end
#
# Y = iY;

# %%
###right now we have rent_index, err_index

# %%
rent_index.head(5)
# Out:
#         Date  MetroArea SECTOR       value
# 0   1/1/2001  Nashville    RET  108.075066
# 1   4/1/2001  Nashville    RET  114.003481
# 2   7/1/2001  Nashville    RET   42.707525
# 3  10/1/2001  Nashville    RET   96.906134
# 4   1/1/2002  Nashville    RET   72.628905

# %%
#len(rent_index)
#len(rent_index[rent_index.MetroArea.str.contains('Honolulu')])+len(rent_index[rent_index.MetroArea.str.contains('Charlotte')])
# Out:
# 12005

# %%
rent_index=rent_index[~rent_index['MetroArea'].str.contains('Honolulu')]
rent_index=rent_index[~rent_index['MetroArea'].str.contains('SW Florida')]
# Out:
#             Date     MetroArea SECTOR       value
# 0       1/1/2001     Nashville    RET  108.075066
# 1       4/1/2001     Nashville    RET  114.003481
# 2       7/1/2001     Nashville    RET   42.707525
# 3      10/1/2001     Nashville    RET   96.906134
# 4       1/1/2002     Nashville    RET   72.628905
# 5       4/1/2002     Nashville    RET  157.068032
# 6       7/1/2002     Nashville    RET  127.524414
# 7      10/1/2002     Nashville    RET  102.941412
# 8       1/1/2003     Nashville    RET  104.708210
# 9       4/1/2003     Nashville    RET   61.335350
# 10      7/1/2003     Nashville    RET   99.471304
# 11     10/1/2003     Nashville    RET   86.902202
# 12      1/1/2004     Nashville    RET  262.480486
# 13      4/1/2004     Nashville    RET   79.207314
# 14      7/1/2004     Nashville    RET   55.210643
# 15     10/1/2004     Nashville    RET  135.516925
# 16      1/1/2005     Nashville    RET  108.431158
# 17      4/1/2005     Nashville    RET  103.128283
# 18      7/1/2005     Nashville    RET  118.900110
# 19     10/1/2005     Nashville    RET   99.296171
# 20      1/1/2006     Nashville    RET  144.998062
# 21      4/1/2006     Nashville    RET   77.919548
# 22      7/1/2006     Nashville    RET  103.204087
# 23     10/1/2006     Nashville    RET   71.936692
# 24      1/1/2007     Nashville    RET  105.685750
# 25      4/1/2007     Nashville    RET  166.160404
# 26      7/1/2007     Nashville    RET   93.812383
# 27     10/1/2007     Nashville    RET  101.060677
# 28      1/1/2008     Nashville    RET  146.800807
# 29      4/1/2008     Nashville    RET  218.103737
# ...          ...           ...    ...         ...
# 12066   4/1/2009  Jacksonville    IND   47.820438
# 12067   7/1/2009  Jacksonville    IND   52.216814
# 12068  10/1/2009  Jacksonville    IND   44.190007
# 12069   1/1/2010  Jacksonville    IND   36.312532
# 12070   4/1/2010  Jacksonville    IND   47.587007
# 12071   7/1/2010  Jacksonville    IND   40.539076
# 12072  10/1/2010  Jacksonville    IND   46.542567
# 12073   1/1/2011  Jacksonville    IND   49.968463
# 12074   4/1/2011  Jacksonville    IND   44.496231
# 12075   7/1/2011  Jacksonville    IND   40.131616
# 12076  10/1/2011  Jacksonville    IND   41.171085
# 12077   1/1/2012  Jacksonville    IND   43.877279
# 12078   4/1/2012  Jacksonville    IND   40.539625
# 12079   7/1/2012  Jacksonville    IND   26.480752
# 12080  10/1/2012  Jacksonville    IND   50.115905
# 12081   1/1/2013  Jacksonville    IND   45.540769
# 12082   4/1/2013  Jacksonville    IND   56.256767
# 12083   7/1/2013  Jacksonville    IND   41.128836
# 12084  10/1/2013  Jacksonville    IND   16.985646
# 12085   1/1/2014  Jacksonville    IND   79.967250
# 12086   4/1/2014  Jacksonville    IND   39.233397
# 12087   7/1/2014  Jacksonville    IND   76.852327
# 12088  10/1/2014  Jacksonville    IND   47.356601
# 12089   1/1/2015  Jacksonville    IND   78.125491
# 12090   4/1/2015  Jacksonville    IND   45.292898
# 12091   7/1/2015  Jacksonville    IND   62.150408
# 12092  10/1/2015  Jacksonville    IND   46.034938
# 12093   1/1/2016  Jacksonville    IND   47.969453
# 12094   4/1/2016  Jacksonville    IND   37.827490
# 12095   7/1/2016  Jacksonville    IND   65.576719
#
# [11523 rows x 4 columns]

# %% [markdown]
# ### join metro rent index

# %%
mkpmtf=pd.read_excel('mkp_mtf_2015q4.xls')

# %%
metro_areas=list(set(rent_index.MetroArea))
len(metro_areas)
# Out:
# 46

# %%
#drop Honolulu SW Florida
for area in metro_areas:
    if area not in set(mkpmtf.Metro.str.strip()):
        print(area)

# %%
### Tampa ~ 'Tampa-St. Petersburg'
###NYC Metro ~ New York Metro
###Phila Metro ~ Philadelphia
###DC Metro ~ District of Columbia 
### So Fla ~ Miami
###SW Florida ~ Charlotte 
###SF Metro ~ 'San Francisco'
###LA Metro ~ Los Angeles
###Birmingham(AL) ~ Birmingham
###Honolulu-----
###Norfolk ~Norfolk/Hampton Roads
###St Louis ~ St. Louis
###Raleigh/Durham ~ Raleigh-Durham
### Greensboro ~ Greensboro/Winston-Salem
mkpmtf['Metro']=mkpmtf['Metro'].str.strip()
mkpmtf['Metro.1']=mkpmtf['Metro.1'].str.strip()

# %%
mkpmtf.replace({'Tampa-St. Petersburg' : 'Tampa',
'New York Metro' : 'NYC Metro',
'Philadelphia' : 'Phila Metro' ,
'District of Columbia'  : 'DC Metro',
 'Miami' : 'So Fla' ,
'San Francisco' : 'SF Metro' ,
'Los Angeles' : 'LA Metro',
'Birmingham' : 'Birmingham(AL)',
'Norfolk/Hampton Roads': 'Norfolk',
'St. Louis' : 'St Louis' ,
'Raleigh-Durham' : 'Raleigh/Durham' ,
'Greensboro/Winston-Salem' :'Greensboro'},regex=True,inplace=True)

# %%
# Out:
#              Metro MetroCode      Metro.1 Sector Subsector  Year  Quarter  \
# 0      Albuquerque        AQ  Albuquerque    Apt       ABC  1986        5
# 1      Albuquerque        AQ  Albuquerque    Apt       ABC  1987        5
# 2      Albuquerque        AQ  Albuquerque    Apt       ABC  1988        5
# 3      Albuquerque        AQ  Albuquerque    Apt       ABC  1989        5
# 4      Albuquerque        AQ  Albuquerque    Apt       ABC  1990        5
# 5      Albuquerque        AQ  Albuquerque    Apt       ABC  1991        5
# 6      Albuquerque        AQ  Albuquerque    Apt       ABC  1992        5
# 7      Albuquerque        AQ  Albuquerque    Apt       ABC  1993        5
# 8      Albuquerque        AQ  Albuquerque    Apt       ABC  1994        5
# 9      Albuquerque        AQ  Albuquerque    Apt       ABC  1995        5
# 10     Albuquerque        AQ  Albuquerque    Apt       ABC  1996        5
# 11     Albuquerque        AQ  Albuquerque    Apt       ABC  1997        5
# 12     Albuquerque        AQ  Albuquerque    Apt       ABC  1998        5
# 13     Albuquerque        AQ  Albuquerque    Apt       ABC  1999        5
# 14     Albuquerque        AQ  Albuquerque    Apt       ABC  2000        5
# 15     Albuquerque        AQ  Albuquerque    Apt       ABC  2001        5
# 16     Albuquerque        AQ  Albuquerque    Apt       ABC  2002        5
# 17     Albuquerque        AQ  Albuquerque    Apt       ABC  2003        5
# 18     Albuquerque        AQ  Albuquerque    Apt       ABC  2004        5
# 19     Albuquerque        AQ  Albuquerque    Apt       ABC  2005        5
# 20     Albuquerque        AQ  Albuquerque    Apt       ABC  2006        5
# 21     Albuquerque        AQ  Albuquerque    Apt       ABC  2007        5
# 22     Albuquerque        AQ  Albuquerque    Apt       ABC  2008        5
# 23     Albuquerque        AQ  Albuquerque    Apt       ABC  2009        5
# 24     Albuquerque        AQ  Albuquerque    Apt       ABC  2010        5
# 25     Albuquerque        AQ  Albuquerque    Apt       ABC  2011        1
# 26     Albuquerque        AQ  Albuquerque    Apt       ABC  2011        2
# 27     Albuquerque        AQ  Albuquerque    Apt       ABC  2011        3
# 28     Albuquerque        AQ  Albuquerque    Apt       ABC  2011        4
# 29     Albuquerque        AQ  Albuquerque    Apt       ABC  2011        5
# ...            ...       ...          ...    ...       ...   ...      ...
# 23431  Westchester        WS  Westchester    Ret        NC  2010        5
# 23432  Westchester        WS  Westchester    Ret        NC  2011        1
# 23433  Westchester        WS  Westchester    Ret        NC  2011        2
# 23434  Westchester        WS  Westchester    Ret        NC  2011        3
# 23435  Westchester        WS  Westchester    Ret        NC  2011        4
# 23436  Westchester        WS  Westchester    Ret        NC  2011        5
# 23437  Westchester        WS  Westchester    Ret        NC  2012        1
# 23438  Westchester        WS  Westchester    Ret        NC  2012        2
# 23439  Westchester        WS  Westchester    Ret        NC  2012        3
# 23440  Westchester        WS  Westchester    Ret        NC  2012        4
# 23441  Westchester        WS  Westchester    Ret        NC  2012        5
# 23442  Westchester        WS  Westchester    Ret        NC  2013        1
# 23443  Westchester        WS  Westchester    Ret        NC  2013        2
# 23444  Westchester        WS  Westchester    Ret        NC  2013        3
# 23445  Westchester        WS  Westchester    Ret        NC  2013        4
# 23446  Westchester        WS  Westchester    Ret        NC  2013        5
# 23447  Westchester        WS  Westchester    Ret        NC  2014        1
# 23448  Westchester        WS  Westchester    Ret        NC  2014        2
# 23449  Westchester        WS  Westchester    Ret        NC  2014        3
# 23450  Westchester        WS  Westchester    Ret        NC  2014        4
# 23451  Westchester        WS  Westchester    Ret        NC  2014        5
# 23452  Westchester        WS  Westchester    Ret        NC  2015        1
# 23453  Westchester        WS  Westchester    Ret        NC  2015        2
# 23454  Westchester        WS  Westchester    Ret        NC  2015        3
# 23455  Westchester        WS  Westchester    Ret        NC  2015        4
# 23456  Westchester        WS  Westchester    Ret        NC  2015        5
# 23457  Westchester        WS  Westchester    Ret        NC  2016        5
# 23458  Westchester        WS  Westchester    Ret        NC  2017        5
# 23459  Westchester        WS  Westchester    Ret        NC  2018        5
# 23460  Westchester        WS  Westchester    Ret        NC  2019        5
#
#        Inventory  Completions  Conversions  ...    GrRevUnit  TotalEmp  \
# 0          25610       2687.0          NaN  ...          NaN    252890
# 1          27830       2220.0          NaN  ...       290.00    258640
# 2          28976       1146.0          NaN  ...       317.00    265520
# 3          29320        344.0          NaN  ...       352.00    271830
# 4          29696        376.0          NaN  ...       360.00    271430
# 5          29696          0.0          NaN  ...       405.00    274770
# 6          29896        200.0          NaN  ...       437.00    285530
# 7          29896          0.0          NaN  ...       483.00    302100
# 8          30096        200.0          NaN  ...       527.00    320870
# 9          31570       1474.0          NaN  ...       543.00    325700
# 10         33099       1529.0          NaN  ...       546.00    333900
# 11         33749        650.0          NaN  ...       518.00    341470
# 12         34848       1099.0          NaN  ...       526.00    345500
# 13         35304        456.0          NaN  ...       528.00    353630
# 14         35340         36.0          NaN  ...       559.00    364130
# 15         35469        129.0          NaN  ...       561.00    363370
# 16         35539         70.0          NaN  ...       566.00    363530
# 17         36035        496.0          0.0  ...       564.00    365470
# 18         36486        451.0          0.0  ...       572.00    375800
# 19         36570         84.0          0.0  ...       586.00    384570
# 20         37039        469.0          0.0  ...       615.00    396070
# 21         36889          0.0        -74.0  ...       650.00    397970
# 22         37383        494.0          0.0  ...       667.00    392530
# 23         38033        650.0          0.0  ...       658.00    375830
# 24         38121         88.0          0.0  ...       682.00    373230
# 25         38074          0.0          0.0  ...       687.00    373800
# 26         38074          0.0          0.0  ...       691.00    373200
# 27         38074          0.0          0.0  ...       698.00    371730
# 28         38074          0.0          0.0  ...       697.00    369900
# 29         38074          0.0          0.0  ...       697.00    369900
# ...          ...          ...          ...  ...          ...       ...
# 23431    7766000          0.0          NaN  ...        32.92    421660
# 23432    7766000          0.0          NaN  ...        32.80    423240
# 23433    7766000          0.0          NaN  ...        32.68    424590
# 23434    7766000          0.0          NaN  ...        32.68    425580
# 23435    7766000          0.0          NaN  ...        32.71    426180
# 23436    7766000          0.0          NaN  ...        32.71    426180
# 23437    7766000          0.0          NaN  ...        32.61    426460
# 23438    7766000          0.0          NaN  ...        32.76    426520
# 23439    7872000     106000.0          NaN  ...        32.88    426450
# 23440    7872000          0.0          NaN  ...        32.81    426380
# 23441    7872000     106000.0          NaN  ...        32.81    426380
# 23442    7872000          0.0          NaN  ...        32.78    426460
# 23443    7872000          0.0          NaN  ...        33.01    426840
# 23444    7872000          0.0          NaN  ...        33.30    427670
# 23445    7872000          0.0          NaN  ...        33.30    428970
# 23446    7872000          0.0          NaN  ...        33.30    428970
# 23447    7872000          0.0          NaN  ...        33.37    430590
# 23448    7872000          0.0          NaN  ...        33.51    432400
# 23449    7872000          0.0          NaN  ...        33.75    434290
# 23450    7872000          0.0          NaN  ...        33.91    436180
# 23451    7872000          0.0          NaN  ...        33.91    436180
# 23452    7886000      14000.0          NaN  ...        34.04    438000
# 23453    7886000          0.0          NaN  ...        34.02    439750
# 23454    7886000          0.0          NaN  ...        33.91    441420
# 23455    7886000          0.0          NaN  ...        34.07    443000
# 23456    7886000      14000.0          NaN  ...        34.07    443000
# 23457    7936000      50000.0          NaN  ...        34.90    448590
# 23458    7936000          0.0          NaN  ...        36.06    453760
# 23459    7936000          0.0          NaN  ...        37.29    458330
# 23460    7936000          0.0          NaN  ...        38.64    460670
#
#        OfficeEmp  IndusEmp  Households  Population  HouseholdIncome  Actual  \
# 0          84722     34303      208440      567040            39141       A
# 1          87410     34944      214330      579520            41126       A
# 2          88473     37360      219210      589050            42528       A
# 3          90618     38827      224120      598120            44052       A
# 4          91300     38400      229170      608770            46302       A
# 5          92739     39239      235710      624620            48028       A
# 6          95261     40335      242630      641290            49971       A
# 7          99258     42876      250110      659650            53072       A
# 8         103977     45891      258170      679420            56392       A
# 9         105350     46319      264560      694650            58062       A
# 10        108374     45459      269170      705080            60143       A
# 11        110213     47015      273210      713940            62361       A
# 12        113555     44833      276200      719840            64948       A
# 13        116444     44284      279740      727200            67145       A
# 14        118510     45949      283900      736640            72508       A
# 15        118787     43221      289420      749470            75327       A
# 16        119261     41816      295910      765010            75170       A
# 17        119893     40017      302190      780190            76517       A
# 18        123850     39880      309920      799150            79280       A
# 19        126087     40670      318510      820550            82020       A
# 20        128944     41988      326920      840980            85317       A
# 21        130445     40858      333740      856910            87851       A
# 22        130459     38235      339350      869790            88432       A
# 23        126225     33882      345280      883430            86783       A
# 24        125129     33795      350420      894080            88216       A
# 25        125442     33769      351090      895720            89130       A
# 26        124937     33754      351870      897090            89548       A
# 27        124786     33672      352530      898280            90638       A
# 28        124048     33654      353400      899320            90969       A
# 29        124048     33654      353400      899320            90969       A
# ...          ...       ...         ...         ...              ...     ...
# 23431     132335     39174      348240      953250           199409       A
# 23432     132855     39129      348150      955160           201095       A
# 23433     133320     39095      347970      956830           203513       A
# 23434     133683     39098      347760      958090           207368       A
# 23435     133914     39110      347560      958950           212464       A
# 23436     133914     39110      347560      958950           212464       A
# 23437     134032     39131      347400      959740           217636       A
# 23438     134077     39128      347320      960770           221689       A
# 23439     134104     39077      347360      962360           223556       A
# 23440     134109     38967      347500      964490           223193       A
# 23441     134109     38967      347500      964490           223193       A
# 23442     134127     38851      347670      966770           221707       A
# 23443     134191     38735      347790      968820           220286       A
# 23444     134288     38624      347810      970330           220004       A
# 23445     134471     38551      347700      971210           221212       A
# 23446     134471     38551      347700      971210           221212       A
# 23447     134730     38502      347520      971720           223367       A
# 23448     135093     38498      347320      972170           225885       A
# 23449     135573     38508      347170      972830           228245       A
# 23450     136163     38548      347110      973790           230247       A
# 23451     136163     38548      347110      973790           230247       A
# 23452     136798     38601      347220      974920           232033       A
# 23453     137436     38649      347550      976090           233834       A
# 23454     138055     38680      348150      977200           235888       A
# 23455     138641     38695      349020      978180           238234       A
# 23456     138641     38695      349020      978180           238234       A
# 23457     141126     38732      352940      981510           248669       F
# 23458     143831     38802      356550      984690           259260       F
# 23459     145794     38783      359750      987820           268349       F
# 23460     146905     38645      361250      991130           274656       F
#
#        Tier  Exp30
# 0         1      Y
# 1         1      Y
# 2         1      Y
# 3         1      Y
# 4         1      Y
# 5         1      Y
# 6         1      Y
# 7         1      Y
# 8         1      Y
# 9         1      Y
# 10        1      Y
# 11        1      Y
# 12        1      Y
# 13        1      Y
# 14        1      Y
# 15        1      Y
# 16        1      Y
# 17        1      Y
# 18        1      Y
# 19        1      Y
# 20        1      Y
# 21        1      Y
# 22        1      Y
# 23        1      Y
# 24        1      Y
# 25        1      Y
# 26        1      Y
# 27        1      Y
# 28        1      Y
# 29        1      Y
# ...     ...    ...
# 23431     1      Y
# 23432     1      Y
# 23433     1      Y
# 23434     1      Y
# 23435     1      Y
# 23436     1      Y
# 23437     1      Y
# 23438     1      Y
# 23439     1      Y
# 23440     1      Y
# 23441     1      Y
# 23442     1      Y
# 23443     1      Y
# 23444     1      Y
# 23445     1      Y
# 23446     1      Y
# 23447     1      Y
# 23448     1      Y
# 23449     1      Y
# 23450     1      Y
# 23451     1      Y
# 23452     1      Y
# 23453     1      Y
# 23454     1      Y
# 23455     1      Y
# 23456     1      Y
# 23457     1      Y
# 23458     1      Y
# 23459     1      Y
# 23460     1      Y
#
# [23461 rows x 30 columns]

# %%
metro_areas=list(set(metro_level_data.SubMarkets))

# %%
yield_data=pd.concat([data_corporate_yeild,data_yield],axis=1)
yield_data=yield_data.iloc[0:-1]

# %%
month_list=[]
for year in np.arange(2001,2017):
    for month in ['1','4','7','10']:
        month_list.append("{1}/1/{0}".format(year,month))
month_list=month_list[0:-1]

# %%
yield_data['Date']=month_list

# %%
metro_level_data=metro_level_data.merge(yield_data,on=['Date'],how='left')

# %%
metro_level_data.drop('MetroArea',axis=1,inplace=True)

# %%
metro_level_data.head(5)
# Out:
#         Date SECTOR SubMarkets       cppi  rent       AAA  \
# 0   1/1/2001    ALL     Denver  101.80120   NaN  1.445272
# 1   4/1/2001    ALL     Denver  101.76470   NaN  1.372535
# 2   7/1/2001    ALL     Denver   97.65075   NaN  1.540309
# 3  10/1/2001    ALL     Denver   94.19347   NaN  1.604610
# 4   1/1/2002    ALL     Denver   91.24156   NaN  0.972856
#
#    OTR/USD/10YR (Yield)  USD_GRM_spread
# 0              5.631395        0.869411
# 1              5.850798        0.865767
# 2              5.566358        0.668132
# 3              5.318723        0.695084
# 4              5.650477        0.655690

# %% [markdown]
# ### Map elastic

# %%
elastic={}
elastic['Phila Metro']=[1.65,48]
elastic['DC Metro']=[1.61,43]
elastic['San Diego']=[0.67,5]
elastic['NYC Metro']=[0.76,9]
elastic['Tampa']=[1.0,20]
elastic['SF Metro']=[0.66,4]
elastic['Atlanta']=[2.55,74]
elastic['Denver']=[1.53,41]
elastic['Baltimore']=[1.23,31]
elastic['Phoenix']=[1.61,44]
elastic['LA Metro']=[0.63,2]
elastic['SW Florida']=[3.09,85]
elastic['So Fla']=[0.83,14]
elastic['Boston']=[0.86,15]
elastic['Austin']=[3.0,84]
elastic['Orlando']=[1.12,25]
elastic['Seattle']=[0.88,16]
elastic['Jacksonville']=[1.06,23]
elastic['Houston']=[2.3,68]
elastic['Chicago']=[0.81,12]
elastic['Dallas']=[2.18,63]
elastic['Sacramento']=[1.84,55]

# %%
metro_level_data['log rent']=metro_level_data.rent.apply(math.log)

# %%
metro_level_data['log cppi']=metro_level_data['cppi'].apply(math.log)

# %%
metro_level_data['log 10year rate']=metro_level_data['OTR/USD/10YR (Yield)'].apply(math.log)

# %%
for area in metro_areas:
    if elastic[area][0] < st.median(elastic[area][0] for area in metro_areas):
        elastic[area][1]=1
    else:
        elastic[area][1]=0

# %%
metro_level_data['inelastic']=[elastic[area][1] for area in metro_level_data.SubMarkets]

# %%
metro_level_data['intersect']=metro_level_data['inelastic']*metro_level_data['log 10year rate']

# %%
metro_level_data.dropna(inplace=True)
metro_level_data=metro_level_data.reset_index(drop=True)

# %% [markdown]
# ### handle categorical data below

# %%
enc = preprocessing.LabelEncoder()

# %%
metro_level_data['cat_earea']=enc.fit_transform(metro_level_data.SubMarkets.astype('str'))

# %%
metro_level_data.head(5)
# Out:
#         Date SECTOR SubMarkets       cppi   rent       AAA  \
# 0   1/1/2003    ALL     Denver  101.73820  14.57  1.510287
# 1   4/1/2003    ALL     Denver  102.35750  14.19  1.111341
# 2   7/1/2003    ALL     Denver   98.67167  13.84  0.907526
# 3  10/1/2003    ALL     Denver   95.62849  13.61  0.804417
# 4   1/1/2004    ALL     Denver   93.85298  13.38  0.870123
#
#    OTR/USD/10YR (Yield)  USD_GRM_spread  log rent  log cppi  log 10year rate  \
# 0              4.493046        0.423538  2.678965  4.622403         1.502531
# 1              4.198659        0.306389  2.652537  4.628472         1.434765
# 2              4.789141        0.672906  2.627563  4.591798         1.566351
# 3              4.852250        0.533153  2.610805  4.560471         1.579443
# 4              4.586544        0.505044  2.593761  4.541730         1.523127
#
#    inelastic  intersect  cat_earea
# 0          0        0.0          6
# 1          0        0.0          6
# 2          0        0.0          6
# 3          0        0.0          6
# 4          0        0.0          6

# %%
numb=[]
for number in list(set(metro_level_data['cat_earea'])):
    numb.append([number]) 
enc2 = preprocessing.OneHotEncoder()
enc2.fit(numb)
# Out:
# OneHotEncoder(categorical_features='all', dtype=<class 'float'>,
#        handle_unknown='error', n_values='auto', sparse=True)

# %%
dict_num={}
for i in list(set(metro_level_data.SubMarkets)):
    dict_num[enc.transform(i)]=i

# %%
a=np.array(enc2.transform(metro_level_data['cat_earea'][0]).toarray())
for i in np.arange(1,metro_level_data.shape[0]):
    a=np.append(a,enc2.transform(metro_level_data['cat_earea'][i]).toarray(),axis=0)

# %%
a=pd.DataFrame(a)
a.columns=[dict_num[i] for i in range(len(dict_num))]

# %%
metro_level_data=pd.merge(metro_level_data,a,left_index=True,right_index=True, how='inner')

# %%
regress_x=metro_level_data[['log rent','USD_GRM_spread','AAA','log 10year rate','intersect','Atlanta', 'Austin',
       'Baltimore', 'Boston', 'Chicago', 'DC Metro', 'Dallas', 'Denver',
       'Houston', 'Jacksonville', 'LA Metro', 'NYC Metro', 'Orlando',
       'Phila Metro', 'Phoenix', 'SF Metro', 'SW Florida', 'Sacramento',
       'San Diego', 'Seattle', 'So Fla', 'Tampa']]
regress_y=metro_level_data['log cppi']
model = sm.OLS(regress_y,regress_x)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-ef5442f7bb0e> in <module>()
#       3        'Houston', 'Jacksonville', 'LA Metro', 'NYC Metro', 'Orlando',
#       4        'Phila Metro', 'Phoenix', 'SF Metro', 'SW Florida', 'Sacramento',
# ----> 5        'San Diego', 'Seattle', 'So Fla', 'Tampa']]
#       6 regress_y=metro_level_data['log cppi']
#       7 model = sm.OLS(regress_y,regress_x)
#
# C:\Users\czhu\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1984         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1985             # either boolean or fancy integer index
# -> 1986             return self._getitem_array(key)
#    1987         elif isinstance(key, DataFrame):
#    1988             return self._getitem_frame(key)
#
# C:\Users\czhu\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2028             return self.take(indexer, axis=0, convert=False)
#    2029         else:
# -> 2030             indexer = self.ix._convert_to_indexer(key, axis=1)
#    2031             return self.take(indexer, axis=1, convert=True)
#    2032
#
# C:\Users\czhu\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1208                 mask = check == -1
#    1209                 if mask.any():
# -> 1210                     raise KeyError('%s not in index' % objarr[mask])
#    1211
#    1212                 return _values_from_object(indexer)
#
# KeyError: "['Baltimore' 'Jacksonville' 'SW Florida'] not in index"

# %%
regress_x.head(5)

# %%
results = model.fit()

# %% [markdown]
# ### Regression Result:

# %%
results.summary()

# %% [markdown]
# ### Insample and outsample regression

# %%
metro_level_data['Date2']=pd.to_datetime(metro_level_data.Date)

# %%
me1=metro_level_data[metro_level_data.Date2>='2016-01-01']
me2=metro_level_data[metro_level_data.Date2<'2016-01-01']

# %%
regress_x1=me2[['log rent','USD_GRM_spread','AAA','log 10year rate','intersect','Atlanta', 'Austin',
       'Baltimore', 'Boston', 'Chicago', 'DC Metro', 'Dallas', 'Denver',
       'Houston', 'Jacksonville', 'LA Metro', 'NYC Metro', 'Orlando',
       'Phila Metro', 'Phoenix', 'SF Metro', 'SW Florida', 'Sacramento',
       'San Diego', 'Seattle', 'So Fla', 'Tampa']]
regress_y1=me2['log cppi']
model = sm.OLS(regress_y1,regress_x1)

# %%
results = model.fit()
results.summary()

# %%
regress_x1_test=me1[['log rent','USD_GRM_spread','AAA','log 10year rate','intersect','Atlanta', 'Austin',
       'Baltimore', 'Boston', 'Chicago', 'DC Metro', 'Dallas', 'Denver',
       'Houston', 'Jacksonville', 'LA Metro', 'NYC Metro', 'Orlando',
       'Phila Metro', 'Phoenix', 'SF Metro', 'SW Florida', 'Sacramento',
       'San Diego', 'Seattle', 'So Fla', 'Tampa']]
regress_y1_test=me1['log cppi']

# %%
def r_sqaure(y_true,y_fit):
    SSR=(y_fit-st.mean(y_true)).dot(y_fit-st.mean(y_true))
    TSR=(y_true-st.mean(y_true)).dot(y_true-st.mean(y_true))
    return SSR/TSR

# %%
r_sqaure(regress_y1_test,results.predict(regress_x1_test))
